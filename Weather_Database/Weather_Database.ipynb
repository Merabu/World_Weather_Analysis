# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 783

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
#https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&exclude={part}&appid={API key}
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b8158ae32da444bf4aac5f4a85111cc

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]        
       # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
                          #"Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | ponta do sol
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | puerto escondido
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | sindon
# Processing Record 9 of Set 1 | bambous virieux
# Processing Record 10 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 1 | los llanos de aridane
# Processing Record 12 of Set 1 | kidal
# Processing Record 13 of Set 1 | kizukuri
# Processing Record 14 of Set 1 | clyde river
# Processing Record 15 of Set 1 | kargil
# Processing Record 16 of Set 1 | havoysund
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | tadine
# Processing Record 20 of Set 1 | chokurdakh
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | vestmannaeyjar
# Processing Record 23 of Set 1 | komsomolskiy
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | lalmohan
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | airai
# Processing Record 30 of Set 1 | cherskiy
# Processing Record 31 of Set 1 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | kodino
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | geraldton
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | shirdi
# Processing Record 43 of Set 1 | chicama
# Processing Record 44 of Set 1 | tiarei
# Processing Record 45 of Set 1 | cayenne
# Processing Record 46 of Set 1 | zimovniki
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | dubbo
# Processing Record 49 of Set 1 | hambantota
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | east london
# Processing Record 2 of Set 2 | chuy
# Processing Record 3 of Set 2 | soria
# Processing Record 4 of Set 2 | salym
# Processing Record 5 of Set 2 | mount gambier
# Processing Record 6 of Set 2 | baykit
# Processing Record 7 of Set 2 | laguna
# Processing Record 8 of Set 2 | klaksvik
# Processing Record 9 of Set 2 | tayoltita
# Processing Record 10 of Set 2 | fortuna
# Processing Record 11 of Set 2 | port-gentil
# Processing Record 12 of Set 2 | casablanca
# Processing Record 13 of Set 2 | leningradskiy
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | jamsa
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | korla
# Processing Record 21 of Set 2 | yar-sale
# Processing Record 22 of Set 2 | yefimovskiy
# City not found. Skipping...
# Processing Record 23 of Set 2 | hasaki
# Processing Record 24 of Set 2 | college
# Processing Record 25 of Set 2 | kirakira
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | dobryatino
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | constitucion
# Processing Record 31 of Set 2 | semme
# Processing Record 32 of Set 2 | keith
# Processing Record 33 of Set 2 | srednekolymsk
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | bacungan
# Processing Record 37 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 2 | husavik
# Processing Record 39 of Set 2 | bubaque
# Processing Record 40 of Set 2 | pokosnoye
# Processing Record 41 of Set 2 | codrington
# Processing Record 42 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 2 | belfast
# Processing Record 44 of Set 2 | kodiak
# Processing Record 45 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2 | elliot
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | asau
# Processing Record 49 of Set 2 | hilo
# Processing Record 50 of Set 2 | tuatapere
# Processing Record 1 of Set 3 | villa carlos paz
# Processing Record 2 of Set 3 | talnakh
# Processing Record 3 of Set 3 | tanout
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | oga
# Processing Record 6 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 3 | nkhotakota
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | lagoa
# Processing Record 10 of Set 3 | malindi
# Processing Record 11 of Set 3 | tromso
# Processing Record 12 of Set 3 | novocherkassk
# Processing Record 13 of Set 3 | gamba
# Processing Record 14 of Set 3 | bairnsdale
# Processing Record 15 of Set 3 | acarau
# Processing Record 16 of Set 3 | aykhal
# Processing Record 17 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 3 | guasdualito
# Processing Record 19 of Set 3 | abnub
# Processing Record 20 of Set 3 | ixtapa
# Processing Record 21 of Set 3 | gewane
# Processing Record 22 of Set 3 | mahebourg
# Processing Record 23 of Set 3 | lethbridge
# Processing Record 24 of Set 3 | lebu
# Processing Record 25 of Set 3 | luganville
# Processing Record 26 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 3 | bengkulu
# Processing Record 28 of Set 3 | lodwar
# Processing Record 29 of Set 3 | vao
# Processing Record 30 of Set 3 | terme
# Processing Record 31 of Set 3 | mitu
# Processing Record 32 of Set 3 | yaan
# Processing Record 33 of Set 3 | khilok
# Processing Record 34 of Set 3 | yala
# Processing Record 35 of Set 3 | butaritari
# Processing Record 36 of Set 3 | linxia
# Processing Record 37 of Set 3 | minab
# Processing Record 38 of Set 3 | barrow
# Processing Record 39 of Set 3 | ilhabela
# Processing Record 40 of Set 3 | le port
# Processing Record 41 of Set 3 | mount isa
# Processing Record 42 of Set 3 | pompeia
# Processing Record 43 of Set 3 | batemans bay
# Processing Record 44 of Set 3 | ust-kuyga
# Processing Record 45 of Set 3 | oussouye
# Processing Record 46 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 47 of Set 3 | hualmay
# Processing Record 48 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 3 | vaini
# Processing Record 50 of Set 3 | redmond
# Processing Record 1 of Set 4 | sugag
# Processing Record 2 of Set 4 | humberto de campos
# Processing Record 3 of Set 4 | mardin
# Processing Record 4 of Set 4 | singaparna
# Processing Record 5 of Set 4 | aksarka
# Processing Record 6 of Set 4 | nizhniy kuranakh
# Processing Record 7 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 4 | port antonio
# Processing Record 9 of Set 4 | araguari
# Processing Record 10 of Set 4 | byron bay
# Processing Record 11 of Set 4 | cabatuan
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | harper
# Processing Record 14 of Set 4 | vathi
# Processing Record 15 of Set 4 | zheleznogorsk-ilimskiy
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | aksu
# Processing Record 18 of Set 4 | chauk
# Processing Record 19 of Set 4 | bowen
# Processing Record 20 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 21 of Set 4 | rio grande
# Processing Record 22 of Set 4 | bakel
# Processing Record 23 of Set 4 | tilichiki
# Processing Record 24 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 4 | coquimbo
# Processing Record 27 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 4 | flinders
# Processing Record 29 of Set 4 | ilulissat
# Processing Record 30 of Set 4 | new norfolk
# Processing Record 31 of Set 4 | atasu
# Processing Record 32 of Set 4 | qandahar
# City not found. Skipping...
# Processing Record 33 of Set 4 | kuytun
# Processing Record 34 of Set 4 | longyearbyen
# Processing Record 35 of Set 4 | katete
# Processing Record 36 of Set 4 | tautira
# Processing Record 37 of Set 4 | kaitangata
# Processing Record 38 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 4 | eydhafushi
# Processing Record 40 of Set 4 | rocha
# Processing Record 41 of Set 4 | bada
# Processing Record 42 of Set 4 | victoria
# Processing Record 43 of Set 4 | ribeira grande
# Processing Record 44 of Set 4 | tiksi
# Processing Record 45 of Set 4 | bonthe
# Processing Record 46 of Set 4 | shelburne
# Processing Record 47 of Set 4 | ludvika
# Processing Record 48 of Set 4 | ripoll
# Processing Record 49 of Set 4 | alekseyevskaya
# Processing Record 50 of Set 4 | willowmore
# Processing Record 1 of Set 5 | nsunga
# Processing Record 2 of Set 5 | caravelas
# Processing Record 3 of Set 5 | wuxue
# Processing Record 4 of Set 5 | itarema
# Processing Record 5 of Set 5 | cockburn town
# Processing Record 6 of Set 5 | hithadhoo
# Processing Record 7 of Set 5 | tabou
# Processing Record 8 of Set 5 | ejido hermosillo
# Processing Record 9 of Set 5 | kavieng
# Processing Record 10 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 5 | carutapera
# Processing Record 12 of Set 5 | muli
# Processing Record 13 of Set 5 | pacocha
# Processing Record 14 of Set 5 | glogow
# Processing Record 15 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 5 | cabra
# Processing Record 17 of Set 5 | winslow
# Processing Record 18 of Set 5 | havre-saint-pierre
# Processing Record 19 of Set 5 | saint-pierre
# Processing Record 20 of Set 5 | broome
# Processing Record 21 of Set 5 | sunbury
# Processing Record 22 of Set 5 | ewa beach
# Processing Record 23 of Set 5 | alaca
# Processing Record 24 of Set 5 | kalmunai
# Processing Record 25 of Set 5 | evensk
# Processing Record 26 of Set 5 | nanortalik
# Processing Record 27 of Set 5 | belmonte
# Processing Record 28 of Set 5 | mlowo
# Processing Record 29 of Set 5 | port elizabeth
# Processing Record 30 of Set 5 | mitsamiouli
# Processing Record 31 of Set 5 | araouane
# Processing Record 32 of Set 5 | lompoc
# Processing Record 33 of Set 5 | norman wells
# Processing Record 34 of Set 5 | urucara
# Processing Record 35 of Set 5 | ahipara
# Processing Record 36 of Set 5 | pangai
# Processing Record 37 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 5 | biltine
# Processing Record 39 of Set 5 | lorengau
# Processing Record 40 of Set 5 | alihe
# Processing Record 41 of Set 5 | eyl
# Processing Record 42 of Set 5 | moindou
# Processing Record 43 of Set 5 | faanui
# Processing Record 44 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 45 of Set 5 | haizhou
# Processing Record 46 of Set 5 | torbay
# Processing Record 47 of Set 5 | pelym
# Processing Record 48 of Set 5 | khatanga
# Processing Record 49 of Set 5 | bethel
# Processing Record 50 of Set 5 | tieling
# Processing Record 1 of Set 6 | de-kastri
# Processing Record 2 of Set 6 | te anau
# Processing Record 3 of Set 6 | sisimiut
# Processing Record 4 of Set 6 | avera
# Processing Record 5 of Set 6 | sao jose da coroa grande
# Processing Record 6 of Set 6 | arlit
# Processing Record 7 of Set 6 | san luis rio colorado
# Processing Record 8 of Set 6 | san patricio
# Processing Record 9 of Set 6 | eureka
# Processing Record 10 of Set 6 | okhotsk
# Processing Record 11 of Set 6 | karratha
# Processing Record 12 of Set 6 | beyneu
# Processing Record 13 of Set 6 | fairbanks
# Processing Record 14 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 6 | tyler
# Processing Record 16 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 17 of Set 6 | maraa
# Processing Record 18 of Set 6 | mercedes
# Processing Record 19 of Set 6 | ketchikan
# Processing Record 20 of Set 6 | yulara
# Processing Record 21 of Set 6 | mar del plata
# Processing Record 22 of Set 6 | mandal
# Processing Record 23 of Set 6 | makubetsu
# Processing Record 24 of Set 6 | sioux lookout
# Processing Record 25 of Set 6 | wanning
# Processing Record 26 of Set 6 | falaleu
# City not found. Skipping...
# Processing Record 27 of Set 6 | harnosand
# Processing Record 28 of Set 6 | kruisfontein
# Processing Record 29 of Set 6 | bangui
# Processing Record 30 of Set 6 | alcantara
# Processing Record 31 of Set 6 | gautier
# Processing Record 32 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 6 | sorland
# Processing Record 34 of Set 6 | skjervoy
# Processing Record 35 of Set 6 | batetskiy
# Processing Record 36 of Set 6 | oktyabrskoye
# Processing Record 37 of Set 6 | gibsons
# Processing Record 38 of Set 6 | touros
# Processing Record 39 of Set 6 | mazagao
# Processing Record 40 of Set 6 | bukachacha
# Processing Record 41 of Set 6 | port moresby
# Processing Record 42 of Set 6 | tarata
# Processing Record 43 of Set 6 | jackson
# Processing Record 44 of Set 6 | chelbasskaya
# Processing Record 45 of Set 6 | udachnyy
# Processing Record 46 of Set 6 | port hawkesbury
# Processing Record 47 of Set 6 | coihaique
# Processing Record 48 of Set 6 | angoche
# Processing Record 49 of Set 6 | thinadhoo
# Processing Record 50 of Set 6 | benguela
# Processing Record 1 of Set 7 | tuktoyaktuk
# Processing Record 2 of Set 7 | clovis
# Processing Record 3 of Set 7 | noshiro
# Processing Record 4 of Set 7 | kenai
# Processing Record 5 of Set 7 | saint albans
# Processing Record 6 of Set 7 | buritis
# Processing Record 7 of Set 7 | isangel
# Processing Record 8 of Set 7 | hami
# Processing Record 9 of Set 7 | umm lajj
# Processing Record 10 of Set 7 | singaraja
# Processing Record 11 of Set 7 | saint anthony
# Processing Record 12 of Set 7 | cidreira
# Processing Record 13 of Set 7 | sembakung
# Processing Record 14 of Set 7 | surt
# Processing Record 15 of Set 7 | marienburg
# Processing Record 16 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 7 | castro
# Processing Record 18 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 7 | sena madureira
# Processing Record 20 of Set 7 | cortez
# Processing Record 21 of Set 7 | piranshahr
# Processing Record 22 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 7 | vila franca do campo
# Processing Record 24 of Set 7 | merritt island
# Processing Record 25 of Set 7 | adrar
# Processing Record 26 of Set 7 | liaozhong
# Processing Record 27 of Set 7 | comodoro rivadavia
# Processing Record 28 of Set 7 | ambad
# Processing Record 29 of Set 7 | sabinas
# Processing Record 30 of Set 7 | lukh
# Processing Record 31 of Set 7 | jardim
# Processing Record 32 of Set 7 | cedar city
# Processing Record 33 of Set 7 | santa cruz de la palma
# Processing Record 34 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 7 | wuwei
# Processing Record 36 of Set 7 | naze
# Processing Record 37 of Set 7 | burgeo
# Processing Record 38 of Set 7 | rodrigues alves
# Processing Record 39 of Set 7 | shieli
# Processing Record 40 of Set 7 | trang
# Processing Record 41 of Set 7 | haines junction
# Processing Record 42 of Set 7 | carballo
# Processing Record 43 of Set 7 | margate
# Processing Record 44 of Set 7 | koboldo
# City not found. Skipping...
# Processing Record 45 of Set 7 | yoro
# Processing Record 46 of Set 7 | leh
# Processing Record 47 of Set 7 | tugulym
# Processing Record 48 of Set 7 | praia da vitoria
# Processing Record 49 of Set 7 | ashington
# Processing Record 50 of Set 7 | dalvik
# Processing Record 1 of Set 8 | pohrebyshche
# Processing Record 2 of Set 8 | hay river
# Processing Record 3 of Set 8 | brae
# Processing Record 4 of Set 8 | carnarvon
# Processing Record 5 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 6 of Set 8 | rio hato
# Processing Record 7 of Set 8 | zahesi
# Processing Record 8 of Set 8 | linjiang
# Processing Record 9 of Set 8 | lleida
# Processing Record 10 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 8 | parli
# Processing Record 12 of Set 8 | thompson
# Processing Record 13 of Set 8 | auki
# Processing Record 14 of Set 8 | alice springs
# Processing Record 15 of Set 8 | itabira
# Processing Record 16 of Set 8 | salalah
# Processing Record 17 of Set 8 | patria
# Processing Record 18 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 19 of Set 8 | port blair
# Processing Record 20 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 21 of Set 8 | kisanga
# Processing Record 22 of Set 8 | iquitos
# Processing Record 23 of Set 8 | san felipe
# Processing Record 24 of Set 8 | camacari
# Processing Record 25 of Set 8 | kudat
# Processing Record 26 of Set 8 | ostrovnoy
# Processing Record 27 of Set 8 | takayama
# Processing Record 28 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 29 of Set 8 | fenoarivo
# Processing Record 30 of Set 8 | elizabethtown
# Processing Record 31 of Set 8 | doka
# Processing Record 32 of Set 8 | guerrero negro
# Processing Record 33 of Set 8 | isla mujeres
# Processing Record 34 of Set 8 | bagdarin
# Processing Record 35 of Set 8 | olafsvik
# Processing Record 36 of Set 8 | qui nhon
# Processing Record 37 of Set 8 | paamiut
# Processing Record 38 of Set 8 | kungurtug
# Processing Record 39 of Set 8 | loanda
# Processing Record 40 of Set 8 | sao filipe
# Processing Record 41 of Set 8 | dunedin
# Processing Record 42 of Set 8 | aldan
# Processing Record 43 of Set 8 | susangerd
# Processing Record 44 of Set 8 | jizan
# Processing Record 45 of Set 8 | pemangkat
# Processing Record 46 of Set 8 | chara
# Processing Record 47 of Set 8 | egvekinot
# Processing Record 48 of Set 8 | ponorogo
# Processing Record 49 of Set 8 | opotiki
# Processing Record 50 of Set 8 | chihuahua
# Processing Record 1 of Set 9 | katsuura
# Processing Record 2 of Set 9 | tommot
# Processing Record 3 of Set 9 | pevek
# Processing Record 4 of Set 9 | kishi
# Processing Record 5 of Set 9 | maramba
# Processing Record 6 of Set 9 | lavrentiya
# Processing Record 7 of Set 9 | harrisonburg
# Processing Record 8 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 9 | deputatskiy
# Processing Record 10 of Set 9 | karlskoga
# Processing Record 11 of Set 9 | sitka
# Processing Record 12 of Set 9 | teshie
# Processing Record 13 of Set 9 | panaba
# Processing Record 14 of Set 9 | alekseyevsk
# Processing Record 15 of Set 9 | pleshanovo
# Processing Record 16 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 9 | bulgan
# Processing Record 18 of Set 9 | wagar
# Processing Record 19 of Set 9 | manta
# Processing Record 20 of Set 9 | verkhoyansk
# Processing Record 21 of Set 9 | jambi
# Processing Record 22 of Set 9 | anadyr
# Processing Record 23 of Set 9 | sovetskiy
# Processing Record 24 of Set 9 | praya
# Processing Record 25 of Set 9 | alofi
# Processing Record 26 of Set 9 | beisfjord
# Processing Record 27 of Set 9 | lago da pedra
# Processing Record 28 of Set 9 | kingman
# Processing Record 29 of Set 9 | vardo
# Processing Record 30 of Set 9 | rincon
# Processing Record 31 of Set 9 | ararat
# Processing Record 32 of Set 9 | grindavik
# Processing Record 33 of Set 9 | taoudenni
# Processing Record 34 of Set 9 | souillac
# Processing Record 35 of Set 9 | mgandu
# Processing Record 36 of Set 9 | karpathos
# Processing Record 37 of Set 9 | aizpute
# Processing Record 38 of Set 9 | arys
# Processing Record 39 of Set 9 | kawalu
# Processing Record 40 of Set 9 | huarmey
# Processing Record 41 of Set 9 | belonia
# Processing Record 42 of Set 9 | aginskoye
# Processing Record 43 of Set 9 | beroroha
# Processing Record 44 of Set 9 | port lincoln
# Processing Record 45 of Set 9 | raudeberg
# Processing Record 46 of Set 9 | tongchuan
# Processing Record 47 of Set 9 | dingli
# Processing Record 48 of Set 9 | la rioja
# Processing Record 49 of Set 9 | narsaq
# Processing Record 50 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 1 of Set 10 | batagay-alyta
# Processing Record 2 of Set 10 | cape elizabeth
# City not found. Skipping...
# Processing Record 3 of Set 10 | predivinsk
# Processing Record 4 of Set 10 | port hardy
# Processing Record 5 of Set 10 | palmas de monte alto
# Processing Record 6 of Set 10 | san joaquin
# Processing Record 7 of Set 10 | huaidian
# Processing Record 8 of Set 10 | pisco
# Processing Record 9 of Set 10 | simao
# Processing Record 10 of Set 10 | jalu
# Processing Record 11 of Set 10 | namibe
# Processing Record 12 of Set 10 | roma
# Processing Record 13 of Set 10 | rawson
# Processing Record 14 of Set 10 | antalaha
# Processing Record 15 of Set 10 | beloha
# Processing Record 16 of Set 10 | kysyl-syr
# Processing Record 17 of Set 10 | dakar
# Processing Record 18 of Set 10 | marsh harbour
# Processing Record 19 of Set 10 | lincoln
# Processing Record 20 of Set 10 | burica
# City not found. Skipping...
# Processing Record 21 of Set 10 | foam lake
# Processing Record 22 of Set 10 | padang
# Processing Record 23 of Set 10 | san carlos de bariloche
# Processing Record 24 of Set 10 | pinega
# Processing Record 25 of Set 10 | mananjary
# Processing Record 26 of Set 10 | kastamonu
# Processing Record 27 of Set 10 | bilma
# Processing Record 28 of Set 10 | moose factory
# Processing Record 29 of Set 10 | suntar
# Processing Record 30 of Set 10 | atar
# Processing Record 31 of Set 10 | roald
# Processing Record 32 of Set 10 | havelock
# Processing Record 33 of Set 10 | iskateley
# Processing Record 34 of Set 10 | himora
# City not found. Skipping...
# Processing Record 35 of Set 10 | kiruna
# Processing Record 36 of Set 10 | genhe
# Processing Record 37 of Set 10 | durango
# Processing Record 38 of Set 10 | waipawa
# Processing Record 39 of Set 10 | galle
# Processing Record 40 of Set 10 | rivadavia
# Processing Record 41 of Set 10 | luderitz
# Processing Record 42 of Set 10 | nong chik
# Processing Record 43 of Set 10 | lesnikovo
# Processing Record 44 of Set 10 | port-cartier
# Processing Record 45 of Set 10 | muros
# Processing Record 46 of Set 10 | zalantun
# Processing Record 47 of Set 10 | bull savanna
# Processing Record 48 of Set 10 | henties bay
# Processing Record 49 of Set 10 | kudahuvadhoo
# Processing Record 50 of Set 10 | nome
# Processing Record 1 of Set 11 | ancud
# Processing Record 2 of Set 11 | chitrakonda
# Processing Record 3 of Set 11 | marystown
# Processing Record 4 of Set 11 | basco
# Processing Record 5 of Set 11 | balkanabat
# Processing Record 6 of Set 11 | tiznit
# Processing Record 7 of Set 11 | khanu woralaksaburi
# Processing Record 8 of Set 11 | plettenberg bay
# Processing Record 9 of Set 11 | santa cruz del sur
# Processing Record 10 of Set 11 | derzhavinsk
# Processing Record 11 of Set 11 | porkhov
# Processing Record 12 of Set 11 | el colorado
# Processing Record 13 of Set 11 | tarnobrzeg
# Processing Record 14 of Set 11 | bintulu
# Processing Record 15 of Set 11 | saldanha
# Processing Record 16 of Set 11 | honiara
# Processing Record 17 of Set 11 | esperance
# Processing Record 18 of Set 11 | faya
# Processing Record 19 of Set 11 | rocky mountain house
# Processing Record 20 of Set 11 | quelimane
# Processing Record 21 of Set 11 | vila velha
# Processing Record 22 of Set 11 | estelle
# Processing Record 23 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 24 of Set 11 | kazerun
# Processing Record 25 of Set 11 | hamilton
# Processing Record 26 of Set 11 | farmington
# Processing Record 27 of Set 11 | la ronge
# Processing Record 28 of Set 11 | vermilion
# Processing Record 29 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 11 | hiranagar
# Processing Record 31 of Set 11 | cumberland
# Processing Record 32 of Set 11 | half moon bay
# Processing Record 33 of Set 11 | andenes
# Processing Record 34 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 11 | tsaratanana
# Processing Record 36 of Set 11 | tual
# Processing Record 37 of Set 11 | qaqortoq
# Processing Record 38 of Set 11 | lata
# Processing Record 39 of Set 11 | jaguaribe
# Processing Record 40 of Set 11 | gizo
# Processing Record 41 of Set 11 | voh
# Processing Record 42 of Set 11 | buala
# Processing Record 43 of Set 11 | yumen
# Processing Record 44 of Set 11 | ta khmau
# Processing Record 45 of Set 11 | jaisalmer
# Processing Record 46 of Set 11 | lerwick
# Processing Record 47 of Set 11 | oyem
# Processing Record 48 of Set 11 | vanimo
# Processing Record 49 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 11 | bjornevatn
# Processing Record 1 of Set 12 | kahului
# Processing Record 2 of Set 12 | kalamoton
# City not found. Skipping...
# Processing Record 3 of Set 12 | iguape
# Processing Record 4 of Set 12 | mecca
# Processing Record 5 of Set 12 | zharkent
# Processing Record 6 of Set 12 | pietersburg
# Processing Record 7 of Set 12 | sola
# Processing Record 8 of Set 12 | san juan
# Processing Record 9 of Set 12 | zaysan
# Processing Record 10 of Set 12 | besikduzu
# Processing Record 11 of Set 12 | villazon
# Processing Record 12 of Set 12 | salekhard
# Processing Record 13 of Set 12 | khasan
# Processing Record 14 of Set 12 | morondava
# Processing Record 15 of Set 12 | hauterive
# Processing Record 16 of Set 12 | vallenar
# Processing Record 17 of Set 12 | vostok
# Processing Record 18 of Set 12 | vila praia de ancora
# Processing Record 19 of Set 12 | kearney
# Processing Record 20 of Set 12 | abalak
# Processing Record 21 of Set 12 | santa maria
# Processing Record 22 of Set 12 | barabai
# Processing Record 23 of Set 12 | mahajanga
# Processing Record 24 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 12 | matara
# Processing Record 26 of Set 12 | la asuncion
# Processing Record 27 of Set 12 | ati
# Processing Record 28 of Set 12 | zhicheng
# Processing Record 29 of Set 12 | manzanillo
# Processing Record 30 of Set 12 | kununurra
# Processing Record 31 of Set 12 | pokhara
# Processing Record 32 of Set 12 | dudinka
# Processing Record 33 of Set 12 | chimbote
# Processing Record 34 of Set 12 | presidencia roque saenz pena
# Processing Record 35 of Set 12 | valparaiso
# Processing Record 36 of Set 12 | lewistown
# Processing Record 37 of Set 12 | namatanai
# Processing Record 38 of Set 12 | marovoay
# Processing Record 39 of Set 12 | banda aceh
# Processing Record 40 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 41 of Set 12 | qeshm
# Processing Record 42 of Set 12 | kholodnyy
# Processing Record 43 of Set 12 | guarapari
# Processing Record 44 of Set 12 | aklavik
# Processing Record 45 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 12 | tumen
# Processing Record 47 of Set 12 | aasiaat
# Processing Record 48 of Set 12 | cap malheureux
# Processing Record 49 of Set 12 | erzin
# Processing Record 50 of Set 12 | payo
# Processing Record 1 of Set 13 | aras
# Processing Record 2 of Set 13 | villa union
# Processing Record 3 of Set 13 | santa rita
# Processing Record 4 of Set 13 | gubkinskiy
# Processing Record 5 of Set 13 | pasighat
# Processing Record 6 of Set 13 | saint george
# Processing Record 7 of Set 13 | conceicao do araguaia
# Processing Record 8 of Set 13 | puksoozero
# Processing Record 9 of Set 13 | tura
# Processing Record 10 of Set 13 | the valley
# Processing Record 11 of Set 13 | fianga
# City not found. Skipping...
# Processing Record 12 of Set 13 | port hedland
# Processing Record 13 of Set 13 | gola bazar
# Processing Record 14 of Set 13 | kletskaya
# Processing Record 15 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 13 | ada
# Processing Record 17 of Set 13 | poum
# Processing Record 18 of Set 13 | oranjemund
# Processing Record 19 of Set 13 | mount hagen
# Processing Record 20 of Set 13 | meulaboh
# Processing Record 21 of Set 13 | horuphav
# Processing Record 22 of Set 13 | bonfim
# Processing Record 23 of Set 13 | teknaf
# Processing Record 24 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 25 of Set 13 | beringovskiy
# Processing Record 26 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 27 of Set 13 | kardailovo
# Processing Record 28 of Set 13 | richards bay
# Processing Record 29 of Set 13 | puro
# Processing Record 30 of Set 13 | sungaipenuh
# Processing Record 31 of Set 13 | chumikan
# Processing Record 32 of Set 13 | oktyabrskiy
# Processing Record 33 of Set 13 | kaseda
# Processing Record 34 of Set 13 | tanete
# Processing Record 35 of Set 13 | talaya
# Processing Record 36 of Set 13 | riyadh
# Processing Record 37 of Set 13 | inongo
# Processing Record 38 of Set 13 | midleton
# Processing Record 39 of Set 13 | north charleston
# Processing Record 40 of Set 13 | shingu
# Processing Record 41 of Set 13 | jamalpur
# Processing Record 42 of Set 13 | lac-megantic
# Processing Record 43 of Set 13 | champerico
# Processing Record 44 of Set 13 | san jose de los arroyos
# City not found. Skipping...
# Processing Record 45 of Set 13 | pasni
# Processing Record 46 of Set 13 | acapulco
# Processing Record 47 of Set 13 | labuhan
# Processing Record 48 of Set 13 | berlevag
# Processing Record 49 of Set 13 | karaton
# Processing Record 50 of Set 13 | dubovka
# Processing Record 1 of Set 14 | dillon
# Processing Record 2 of Set 14 | sao joao da barra
# Processing Record 3 of Set 14 | dawei
# Processing Record 4 of Set 14 | kupang
# Processing Record 5 of Set 14 | nemuro
# Processing Record 6 of Set 14 | lokosovo
# Processing Record 7 of Set 14 | pontianak
# Processing Record 8 of Set 14 | aden
# Processing Record 9 of Set 14 | raozan
# City not found. Skipping...
# Processing Record 10 of Set 14 | gornyy
# Processing Record 11 of Set 14 | samarai
# Processing Record 12 of Set 14 | judenburg
# Processing Record 13 of Set 14 | arman
# Processing Record 14 of Set 14 | palu
# Processing Record 15 of Set 14 | san juan del cesar
# Processing Record 16 of Set 14 | ust-nera
# Processing Record 17 of Set 14 | tacoronte
# Processing Record 18 of Set 14 | kamaishi
# Processing Record 19 of Set 14 | kaya
# Processing Record 20 of Set 14 | omsukchan
# Processing Record 21 of Set 14 | porto novo
# Processing Record 22 of Set 14 | grand gaube
# Processing Record 23 of Set 14 | fayaoue
# Processing Record 24 of Set 14 | sheboygan
# Processing Record 25 of Set 14 | maniitsoq
# Processing Record 26 of Set 14 | dickinson
# Processing Record 27 of Set 14 | sidhauli
# Processing Record 28 of Set 14 | bathsheba
# Processing Record 29 of Set 14 | carndonagh
# Processing Record 30 of Set 14 | mount pleasant
# Processing Record 31 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 32 of Set 14 | muromtsevo
# Processing Record 33 of Set 14 | dawlatabad
# Processing Record 34 of Set 14 | talcahuano
# Processing Record 35 of Set 14 | deoria
# Processing Record 36 of Set 14 | imbituba
# Processing Record 37 of Set 14 | dingle
# Processing Record 38 of Set 14 | mareeba
# Processing Record 39 of Set 14 | omboue
# Processing Record 40 of Set 14 | biak
# Processing Record 41 of Set 14 | westport
# Processing Record 42 of Set 14 | dumas
# Processing Record 43 of Set 14 | terra santa
# Processing Record 44 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 14 | mwingi
# Processing Record 46 of Set 14 | tigil
# Processing Record 47 of Set 14 | izhma
# Processing Record 48 of Set 14 | monroe
# Processing Record 49 of Set 14 | zhigansk
# Processing Record 50 of Set 14 | sishui
# Processing Record 1 of Set 15 | kampene
# Processing Record 2 of Set 15 | linqiong
# Processing Record 3 of Set 15 | xining
# Processing Record 4 of Set 15 | yelan
# Processing Record 5 of Set 15 | tari
# Processing Record 6 of Set 15 | laizhou
# Processing Record 7 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 8 of Set 15 | saint-joseph
# Processing Record 9 of Set 15 | ahuimanu
# Processing Record 10 of Set 15 | ternate
# Processing Record 11 of Set 15 | tarabuco
# Processing Record 12 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 13 of Set 15 | gat
# Processing Record 14 of Set 15 | kuah
# Processing Record 15 of Set 15 | kundiawa
# Processing Record 16 of Set 15 | ulety
# Processing Record 17 of Set 15 | houma
# Processing Record 18 of Set 15 | neuquen
# Processing Record 19 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 20 of Set 15 | nova londrina
# Processing Record 21 of Set 15 | dhidhdhoo
# Processing Record 22 of Set 15 | saint-georges
# Processing Record 23 of Set 15 | kribi
# Processing Record 24 of Set 15 | sur
# Processing Record 25 of Set 15 | goundam
# Processing Record 26 of Set 15 | sokolovo
# Processing Record 27 of Set 15 | miri
# Processing Record 28 of Set 15 | bentiu
# Processing Record 29 of Set 15 | skagen
# Processing Record 30 of Set 15 | botngard
# Processing Record 31 of Set 15 | calabozo
# Processing Record 32 of Set 15 | amurzet
# Processing Record 33 of Set 15 | warrnambool
# Processing Record 34 of Set 15 | mizan teferi
# Processing Record 35 of Set 15 | yellandu
# Processing Record 36 of Set 15 | dale
# Processing Record 37 of Set 15 | scalloway
# City not found. Skipping...
# Processing Record 38 of Set 15 | milkovo
# Processing Record 39 of Set 15 | coahuayana
# Processing Record 40 of Set 15 | paita
# Processing Record 41 of Set 15 | belyy yar
# Processing Record 42 of Set 15 | billund
# Processing Record 43 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 15 | daloa
# Processing Record 45 of Set 15 | esso
# Processing Record 46 of Set 15 | ixcatepec
# Processing Record 47 of Set 15 | pacific grove
# Processing Record 48 of Set 15 | rongcheng
# Processing Record 49 of Set 15 | dongsheng
# Processing Record 50 of Set 15 | kaka
# Processing Record 1 of Set 16 | yanam
# Processing Record 2 of Set 16 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 16 | hazorasp
# Processing Record 4 of Set 16 | perbaungan
# Processing Record 5 of Set 16 | kirovskiy
# Processing Record 6 of Set 16 | baraboo
# Processing Record 7 of Set 16 | show low
# Processing Record 8 of Set 16 | general roca
# Processing Record 9 of Set 16 | stokmarknes
# Processing Record 10 of Set 16 | jiroft
# City not found. Skipping...
# Processing Record 11 of Set 16 | pueblo
# Processing Record 12 of Set 16 | khalkhal
# Processing Record 13 of Set 16 | kiunga
# Processing Record 14 of Set 16 | matagami
# Processing Record 15 of Set 16 | saru dornei
# Processing Record 16 of Set 16 | malinyi
# Processing Record 17 of Set 16 | kokoda
# Processing Record 18 of Set 16 | derbent
# Processing Record 19 of Set 16 | baghdad
# Processing Record 20 of Set 16 | chapais
# Processing Record 21 of Set 16 | quatre cocos
# Processing Record 22 of Set 16 | winnemucca
# Processing Record 23 of Set 16 | eregli
# Processing Record 24 of Set 16 | yuzhno-kurilsk
# Processing Record 25 of Set 16 | belaya gora
# Processing Record 26 of Set 16 | noumea
# Processing Record 27 of Set 16 | crab hill
# City not found. Skipping...
# Processing Record 28 of Set 16 | caucasia
# Processing Record 29 of Set 16 | kashi
# Processing Record 30 of Set 16 | sorong
# Processing Record 31 of Set 16 | atambua
# Processing Record 32 of Set 16 | seoul
# Processing Record 33 of Set 16 | prestea
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 712

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Ponta Do Sol  32.6667  -17.1000     61.72        70          90
# 1                Ushuaia -54.8000  -68.3000     56.86        62          20
# 2           Punta Arenas -53.1500  -70.9167     55.51        76          75
# 3       Puerto Escondido  15.8500  -97.0667     79.63        73          40
# 4                 Atuona  -9.8000 -139.0333     78.94        77          17
# 5                 Sindon  17.0603  122.0151     72.39        93         100
# 6        Bambous Virieux -20.3428   57.7575     80.22        89          75
# 7  Los Llanos De Aridane  28.6585  -17.9182     58.75        77         100
# 8                  Kidal  18.4411    1.4078     62.02        19           8
# 9               Kizukuri  40.8061  140.3861     35.94        83         100
#
#    Wind Speed Country          Current Description
# 0        8.30      PT              overcast clouds
# 1        4.61      AR                   few clouds
# 2       11.50      CL  light intensity shower rain
# 3        5.75      MX             scattered clouds
# 4       18.25      PF                   few clouds
# 5        2.77      PH              overcast clouds
# 6       13.80      MU                   light rain
# 7        8.01      ES              overcast clouds
# 8        7.49      ML                    clear sky
# 9       13.44      JP                   light snow

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]
# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = city_data_df[new_column_order]
# Display sample data
# YOUR CODE HERE
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Ponta Do Sol      PT  32.6667  -17.1000     61.72        70
# 1                Ushuaia      AR -54.8000  -68.3000     56.86        62
# 2           Punta Arenas      CL -53.1500  -70.9167     55.51        76
# 3       Puerto Escondido      MX  15.8500  -97.0667     79.63        73
# 4                 Atuona      PF  -9.8000 -139.0333     78.94        77
# 5                 Sindon      PH  17.0603  122.0151     72.39        93
# 6        Bambous Virieux      MU -20.3428   57.7575     80.22        89
# 7  Los Llanos De Aridane      ES  28.6585  -17.9182     58.75        77
# 8                  Kidal      ML  18.4411    1.4078     62.02        19
# 9               Kizukuri      JP  40.8061  140.3861     35.94        83
#
#    Cloudiness  Wind Speed          Current Description
# 0          90        8.30              overcast clouds
# 1          20        4.61                   few clouds
# 2          75       11.50  light intensity shower rain
# 3          40        5.75             scattered clouds
# 4          17       18.25                   few clouds
# 5         100        2.77              overcast clouds
# 6          75       13.80                   light rain
# 7         100        8.01              overcast clouds
# 8           8        7.49                    clear sky
# 9         100       13.44                   light snow

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(output_data_file, index_label="City_ID")
