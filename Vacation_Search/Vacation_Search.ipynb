# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
# YOUR CODE HERE
city_data_df = pd.read_csv('../Weather_database/WeatherPy_Database.csv')
# Display sample data
# YOUR CODE HERE
city_data_df.head()
# Out:
#    City_ID              City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Ponta Do Sol      PT  32.6667  -17.1000     61.72        70
# 1        1           Ushuaia      AR -54.8000  -68.3000     56.86        62
# 2        2      Punta Arenas      CL -53.1500  -70.9167     55.51        76
# 3        3  Puerto Escondido      MX  15.8500  -97.0667     79.63        73
# 4        4            Atuona      PF  -9.8000 -139.0333     78.94        77
#
#    Cloudiness  Wind Speed          Current Description
# 0          90        8.30              overcast clouds
# 1          20        4.61                   few clouds
# 2          75       11.50  light intensity shower rain
# 3          40        5.75             scattered clouds
# 4          17       18.25                   few clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
# YOUR CODE HERE
min_temp= float(input("What's the minimum temperature you'd like on your vacation?"))
max_temp= float(input("What's the maximum temperature you'd like on your vacation?"))
# Out:
# What's the minimum temperature you'd like on your vacation?75
# What's the maximum temperature you'd like on your vacation?100

# %% [markdown]
# #Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
# YOUR CODE HERE
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]
# Display sample data
# YOUR CODE HERE
preferred_cities_df.head(10)
# Out:
#     City_ID              City Country      Lat       Lng  Max Temp  Humidity  \
# 3         3  Puerto Escondido      MX  15.8500  -97.0667     79.63        73
# 4         4            Atuona      PF  -9.8000 -139.0333     78.94        77
# 6         6   Bambous Virieux      MU -20.3428   57.7575     80.22        89
# 28       28             Kapaa      US  22.0752 -159.3190     80.92        73
# 30       30         Geraldton      AU -28.7667  114.6000     97.21        24
# 33       33            Avarua      CK -21.2078 -159.7750     82.45        69
# 36       36            Tiarei      PF -17.5333 -149.3333     84.22        78
# 37       37           Cayenne      GF   4.9333  -52.3333     75.24        94
# 39       39           Mataura      NZ -46.1927  168.8643     79.29        36
# 40       40             Dubbo      AU -32.2500  148.6167     93.33        26
#
#     Cloudiness  Wind Speed Current Description
# 3           40        5.75    scattered clouds
# 4           17       18.25          few clouds
# 6           75       13.80          light rain
# 28           0        9.22           clear sky
# 30           0       18.41           clear sky
# 33          40        4.61    scattered clouds
# 36           7       10.63          light rain
# 37          97        1.14     overcast clouds
# 39           2        2.24           clear sky
# 40           4        8.05           clear sky

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
# YOUR CODE HERE
clean_travel_cities = preferred_cities_df.dropna()

# Display sample data
# YOUR CODE HERE
clean_travel_cities.head(10)
# Out:
#     City_ID              City Country      Lat       Lng  Max Temp  Humidity  \
# 3         3  Puerto Escondido      MX  15.8500  -97.0667     79.63        73
# 4         4            Atuona      PF  -9.8000 -139.0333     78.94        77
# 6         6   Bambous Virieux      MU -20.3428   57.7575     80.22        89
# 28       28             Kapaa      US  22.0752 -159.3190     80.92        73
# 30       30         Geraldton      AU -28.7667  114.6000     97.21        24
# 33       33            Avarua      CK -21.2078 -159.7750     82.45        69
# 36       36            Tiarei      PF -17.5333 -149.3333     84.22        78
# 37       37           Cayenne      GF   4.9333  -52.3333     75.24        94
# 39       39           Mataura      NZ -46.1927  168.8643     79.29        36
# 40       40             Dubbo      AU -32.2500  148.6167     93.33        26
#
#     Cloudiness  Wind Speed Current Description
# 3           40        5.75    scattered clouds
# 4           17       18.25          few clouds
# 6           75       13.80          light rain
# 28           0        9.22           clear sky
# 30           0       18.41           clear sky
# 33          40        4.61    scattered clouds
# 36           7       10.63          light rain
# 37          97        1.14     overcast clouds
# 39           2        2.24           clear sky
# 40           4        8.05           clear sky

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
# YOUR CODE HERE
hotel_df = clean_travel_cities[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
# YOUR CODE HERE
hotel_df["Hotel Name"] = ""
# Display sample data
# YOUR CODE HERE
hotel_df.head(10)
# Out:
#                 City Country  Max Temp Current Description      Lat       Lng  \
# 3   Puerto Escondido      MX     79.63    scattered clouds  15.8500  -97.0667
# 4             Atuona      PF     78.94          few clouds  -9.8000 -139.0333
# 6    Bambous Virieux      MU     80.22          light rain -20.3428   57.7575
# 28             Kapaa      US     80.92           clear sky  22.0752 -159.3190
# 30         Geraldton      AU     97.21           clear sky -28.7667  114.6000
# 33            Avarua      CK     82.45    scattered clouds -21.2078 -159.7750
# 36            Tiarei      PF     84.22          light rain -17.5333 -149.3333
# 37           Cayenne      GF     75.24     overcast clouds   4.9333  -52.3333
# 39           Mataura      NZ     79.29           clear sky -46.1927  168.8643
# 40             Dubbo      AU     93.33           clear sky -32.2500  148.6167
#
#    Hotel Name
# 3
# 4
# 6
# 28
# 30
# 33
# 36
# 37
# 39
# 40

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Puerto Escondido - nearest hotel: No hotel found
# Atuona - nearest hotel: No hotel found
# Bambous Virieux - nearest hotel: No hotel found
# Kapaa - nearest hotel: No hotel found
# Geraldton - nearest hotel: No hotel found
# Avarua - nearest hotel: No hotel found
# Tiarei - nearest hotel: No hotel found
# Cayenne - nearest hotel: No hotel found
# Mataura - nearest hotel: No hotel found
# Dubbo - nearest hotel: No hotel found
# Hambantota - nearest hotel: No hotel found
# Rikitea - nearest hotel: No hotel found
# East London - nearest hotel: No hotel found
# Port-Gentil - nearest hotel: No hotel found
# Puerto Ayora - nearest hotel: No hotel found
# Kirakira - nearest hotel: No hotel found
# Saint-Philippe - nearest hotel: No hotel found
# Bacungan - nearest hotel: No hotel found
# Bubaque - nearest hotel: No hotel found
# Hilo - nearest hotel: No hotel found
# Malindi - nearest hotel: No hotel found
# Gamba - nearest hotel: No hotel found
# Acarau - nearest hotel: No hotel found
# Guasdualito - nearest hotel: No hotel found
# Mahebourg - nearest hotel: No hotel found
# Luganville - nearest hotel: No hotel found
# Bengkulu - nearest hotel: No hotel found
# Lodwar - nearest hotel: No hotel found
# Vao - nearest hotel: No hotel found
# Yala - nearest hotel: No hotel found
# Butaritari - nearest hotel: No hotel found
# Ilhabela - nearest hotel: No hotel found
# Le Port - nearest hotel: No hotel found
# Mount Isa - nearest hotel: No hotel found
# Batemans Bay - nearest hotel: No hotel found
# Vaini - nearest hotel: No hotel found
# Singaparna - nearest hotel: No hotel found
# Port Antonio - nearest hotel: No hotel found
# Byron Bay - nearest hotel: No hotel found
# Cabatuan - nearest hotel: No hotel found
# Georgetown - nearest hotel: No hotel found
# Harper - nearest hotel: No hotel found
# Bowen - nearest hotel: No hotel found
# Flinders - nearest hotel: No hotel found
# Tautira - nearest hotel: No hotel found
# Eydhafushi - nearest hotel: No hotel found
# Willowmore - nearest hotel: No hotel found
# Itarema - nearest hotel: No hotel found
# Cockburn Town - nearest hotel: No hotel found
# Hithadhoo - nearest hotel: No hotel found
# Tabou - nearest hotel: No hotel found
# Kavieng - nearest hotel: No hotel found
# Muli - nearest hotel: No hotel found
# Saint-Pierre - nearest hotel: No hotel found
# Ewa Beach - nearest hotel: No hotel found
# Kalmunai - nearest hotel: No hotel found
# Belmonte - nearest hotel: No hotel found
# Mitsamiouli - nearest hotel: No hotel found
# Pangai - nearest hotel: No hotel found
# Lorengau - nearest hotel: No hotel found
# Moindou - nearest hotel: No hotel found
# Faanui - nearest hotel: No hotel found
# Te Anau - nearest hotel: No hotel found
# Sao Jose Da Coroa Grande - nearest hotel
nearest hotel: No hotel found
# Labuhan - nearest hotel: No hotel found
# Karaton - nearest hotel: No hotel found
# Dawei - nearest hotel: No hotel found
# Kupang - nearest hotel: No hotel found
# Pontianak - nearest hotel: No hotel found
# Aden - nearest hotel: No hotel found
# Samarai - nearest hotel: No hotel found
# Palu - nearest hotel: No hotel found
# San Juan Del Cesar - nearest hotel: No hotel found
# Grand Gaube - nearest hotel: No hotel found
# Fayaoue - nearest hotel: No hotel found
# Bathsheba - nearest hotel: No hotel found
# Imbituba - nearest hotel: No hotel found
# Dingle - nearest hotel: No hotel found
# Mareeba - nearest hotel: No hotel found
# Omboue - nearest hotel: No hotel found
# Biak - nearest hotel: No hotel found
# Saint-Joseph - nearest hotel: No hotel found
# Ahuimanu - nearest hotel: No hotel found
# Ternate - nearest hotel: No hotel found
# Kuah - nearest hotel: No hotel found
# Dhidhdhoo - nearest hotel: No hotel found
# Saint-Georges - nearest hotel: No hotel found
# Kribi - nearest hotel: No hotel found
# Miri - nearest hotel: No hotel found
# Calabozo - nearest hotel: No hotel found
# Yanam - nearest hotel: No hotel found
# Perbaungan - nearest hotel: No hotel found
# Kiunga - nearest hotel: No hotel found
# Kokoda - nearest hotel: No hotel found
# Quatre Cocos - nearest hotel: No hotel found
# Noumea - nearest hotel: No hotel found
# Sorong - nearest hotel: No hotel found
# Atambua - nearest hotel: No hotel found
#                  City Country  Max Temp Current Description      Lat  \
# 3    Puerto Escondido      MX     79.63    scattered clouds  15.8500
# 4              Atuona      PF     78.94          few clouds  -9.8000
# 6     Bambous Virieux      MU     80.22          light rain -20.3428
# 28              Kapaa      US     80.92           clear sky  22.0752
# 30          Geraldton      AU     97.21           clear sky -28.7667
# ..                ...     ...       ...                 ...      ...
# 696            Kokoda      PG     84.79     overcast clouds  -8.8785
# 700      Quatre Cocos      MU     80.10          light rain -20.2078
# 705            Noumea      NC     84.00     overcast clouds -22.2763
# 708            Sorong      ID     83.86          light rain  -0.8833
# 709           Atambua      ID     82.45     overcast clouds  -9.1061
#
#           Lng      Hotel Name
# 3    -97.0667  No hotel found
# 4   -139.0333  No hotel found
# 6     57.7575  No hotel found
# 28  -159.3190  No hotel found
# 30   114.6000  No hotel found
# ..        ...             ...
# 696  147.7407  No hotel found
# 700   57.7625  No hotel found
# 705  166.4572  No hotel found
# 708  131.2500  No hotel found
# 709  124.8925  No hotel found
#
# [179 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df[hotel_df["Hotel Name"] != "No hotel found"]

# Display sample data
clean_hotel_df
# Out:
# Empty DataFrame
# Columns: [City, Country, Max Temp, Current Description, Lat, Lng, Hotel Name]
# Index: []

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"

# Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
hotel_map = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["Hotel Name", "Country","Current Description"]
)

# Display the map
hotel_map
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\envs\pythonData\lib\site-packages\hvplot\util.py in process_crs(crs)
#     229     try:
# --> 230         import cartopy.crs as ccrs
#     231         import geoviews as gv # noqa
#
# ModuleNotFoundError: No module named 'cartopy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13120\3373849176.py in <module>
#      10     scale = 1,
#      11     color = "City",
# ---> 12     hover_cols = ["Hotel Name", "Country","Current Description"]
#      13 )
#      14
#
# ~\anaconda3\envs\pythonData\lib\site-packages\hvplot\plotting\core.py in points(self, x, y, **kwds)
#    1610         - HoloViews: https://holoviews.org/reference/elements/bokeh/Points.html
#    1611         """
# -> 1612         return self(x, y, kind="points", **kwds)
#    1613
#    1614     def vectorfield(self, x=None, y=None, angle=None, mag=None, **kwds):
#
# ~\anaconda3\envs\pythonData\lib\site-packages\hvplot\plotting\core.py in __call__(self, x, y, kind, **kwds)
#      90                 return pn.panel(plot, **panel_dict)
#      91
# ---> 92         return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      93
#      94     def _get_converter(self, x=None, y=None, kind=None, **kwds):
#
# ~\anaconda3\envs\pythonData\lib\site-packages\hvplot\plotting\core.py in _get_converter(self, x, y, kind, **kwds)
#      97         y = y or params.pop("y", None)
#      98         kind = kind or params.pop("kind", None)
# ---> 99         return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#     100
#     101     def __dir__(self):
#
# ~\anaconda3\envs\pythonData\lib\site-packages\hvplot\converter.py in __init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     394         self.dynamic = dynamic
#     395         self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 396         self.crs = self._process_crs(data, crs) if self.geo else None
#     397         self.project = project
#     398         self.coastline = coastline
#
# ~\anaconda3\envs\pythonData\lib\site-packages\hvplot\converter.py in _process_crs(self, data, crs)
#     648
#     649         try:
# --> 650             return process_crs(_crs)
#     651         except ValueError:
#     652             # only raise error if crs was specified in kwargs
#
# ~\anaconda3\envs\pythonData\lib\site-packages\hvplot\util.py in process_crs(crs)
#     232         import pyproj
#     233     except ImportError:
# --> 234         raise ImportError('Geographic projection support requires GeoViews, pyproj and cartopy.')
#     235
#     236     if crs is None:
#
# ImportError: Geographic projection support requires GeoViews, pyproj and cartopy.
